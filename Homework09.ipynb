# %% [markdown]
# # -Convert RGB image to grayscale-

# %% [markdown]
# ## RGB image

# %%
import matplotlib.pyplot as plt 
from scipy.misc import imread,imsave
import numpy as np
# %matplotlib inline

rgb_image = imread("a.jpg")
plt.imshow(rgb_image)
# Out:
# c:\users\ivana\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %% [markdown]
# ## Convert rgb image to grayscale

# %%
def convert_to_grayscale(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

    
gray = convert_to_grayscale(rgb_image)    
plt.imshow(gray, cmap = plt.get_cmap('gray'))
plt.show()
